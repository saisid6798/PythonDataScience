# %% [markdown]
# ## Exploratory Data Analysis on the PUBG Dataset

# %%
#Importing the necessary modules
import numpy as np #numerical python
import pandas as pd #pandas for data manipulation
import os #functions for interacting with the operating system
import sys #functions to manipulate various functions in the runtime
import matplotlib.pyplot as plt #for creating visualizations
import seaborn as sns #for creating visualizations
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 100)

# %%
#Importing the Data
df=pd.read_csv("C:\\Users\\Sai Sidharth\\Downloads\\data.csv",index_col='Id')

# %%
#To check the dimensions of the data
df.shape
# Out:
# (1111742, 29)

# %%
df.head(1)
# Out:
#                 Unnamed: 0         groupId         matchId  assists  boosts  damageDealt  DBNOs  \
# Id
# a3e3cea9f2e314     2093518  c9f6eaa81245b5  a3d8693390584c        0       0        25.93      0
#
#                 headshotKills  heals  killPlace  killPoints  kills  killStreaks  longestKill  \
# Id
# a3e3cea9f2e314              0      0         84        1437      0            0          0.0
#
#                 matchDuration  matchType  maxPlace  numGroups  rankPoints  revives  rideDistance  \
# Id
# a3e3cea9f2e314           1403  squad-fpp        31         29          -1        0           0.0
#
#                 roadKills  swimDistance  teamKills  vehicleDestroys  walkDistance  \
# Id
# a3e3cea9f2e314          0           0.0          0                0         151.3
#
#                 weaponsAcquired  winPoints  winPlacePerc
# Id
# a3e3cea9f2e314                1       1525        0.0667

# %%
#To understand the columns in the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills', 'killStreaks', 'longestKill',
#        'matchDuration', 'matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
#Dropping irrelevant columns
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df.shape
# Out:
# (1111742, 28)

# %%
#To get the count of the missing values in the dataset
df.isnull().sum()
# Out:
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
#To check the datatypes of all columns in the dataset
# Function to check the datatypes of all the columns:

def check_datatypes(dataset):
    return dataset.dtypes

print("Datatypes of all the columns:")
check_datatypes(df)
# Out:
# Datatypes of all the columns:
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %%
#Describe
df.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills         heals  \
# count  1.111742e+06  1.111742e+06  1.111742e+06  1.111742e+06   1.111742e+06  1.111742e+06
# mean   2.336738e-01  1.106655e+00  1.307364e+02  6.573612e-01   2.266488e-01  1.370348e+00
# std    5.894028e-01  1.716050e+00  1.711755e+02  1.146023e+00   6.033356e-01  2.683819e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.411000e+01  0.000000e+00   0.000000e+00  0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.859000e+02  1.000000e+00   0.000000e+00  2.000000e+00
# max    1.700000e+01  2.400000e+01  5.990000e+03  3.500000e+01   6.400000e+01  7.300000e+01
#
#           killPlace    killPoints         kills   killStreaks   longestKill  matchDuration  \
# ...

# %%
#Check the missing value of the dataset
df[df['winPlacePerc'].isnull()==True]
# Out:
#                        groupId         matchId  assists  boosts  damageDealt  DBNOs  \
# Id
# f70c74418bb064  12dfbede33f92b  224a123c53e008        0       0          0.0      0
#
#                 headshotKills  heals  killPlace  killPoints  kills  killStreaks  longestKill  \
# Id
# f70c74418bb064              0      0          1           0      0            0          0.0
#
#                 matchDuration matchType  maxPlace  numGroups  rankPoints  revives  rideDistance  \
# Id
# f70c74418bb064              9  solo-fpp         1          1        1574        0           0.0
#
#                 roadKills  swimDistance  teamKills  vehicleDestroys  walkDistance  \
# Id
# f70c74418bb064          0           0.0          0                0           0.0
#
#                 weaponsAcquired  winPoints  winPlacePerc
# Id
# f70c74418bb064                0          0           NaN

# %%
df.shape
# Out:
# (1111742, 28)

# %%
#Dropping the row with missing value
df=df.drop('f70c74418bb064')

# %%
df.shape
# Out:
# (1111741, 28)

# %%
#Check the missing values in the dataset
df.isnull().sum()
# Out:
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
#Functions to identify the numerical features in the dataset
def numeric_features(dataset):
    numeric_col = dataset.select_dtypes(include=np.number).columns.tolist()
    return dataset[numeric_col].head()
    
numeric_columns = numeric_features(df)
print("Numerical Features:")
print(numeric_columns)

print("===="*20)




# Function to identify the categorical features in the dataset

def categorical_features(dataset):
    categorical_col = dataset.select_dtypes(exclude=np.number).columns.tolist()
    return dataset[categorical_col].head()

categorical_columns = categorical_features(df)
print("Categorical Features:")
print(categorical_columns)

print("===="*20)
# Out:
# Numerical Features:
#                 assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  \
# Id
# a3e3cea9f2e314        0       0        25.93      0              0      0         84        1437
# 43e4be7ad72cc7        0       0        36.71      0              0      0         57        1225
# 9a68690e31fdff        0       1        47.73      0              0      0         50           0
# b147e1bd448fc4        0       0         0.00      0              0      0         56        1286
# d818b4edd59612        0       2       100.00      0              0      3         31           0
#
#                 kills  killStreaks  longestKill  matchDuration  maxPlace  numGroups  rankPoints  \
# Id
# a3e3cea9f2e314      0            0        0.000           1403        31         29          -1
# 43e4be7ad72cc7      0            0        0.000           1971        30         30          -1
# ...

# %%
#To check the group id column of the dataset
df['groupId'].value_counts()
# Out:
# 14d6b54cdec6bc    17
# 7385e5fe214021    16
# 128b07271aa012    16
# 6a292d4d1a0207    12
# c8b08c00eb80c0    11
#                   ..
# 5853c3efd52f9a     1
# 5242ae7b9e5a8d     1
# daea4145d1bd7c     1
# 8cf2e3d559f7c9     1
# 5cfa1834dc5b11     1
# Name: groupId, Length: 870621, dtype: int64

# %%
#To check the match id column of the dataset
df['matchId'].value_counts()
# Out:
# 7db80b78103e95    42
# f7182fcc0d8cc8    42
# 9bc88ae66d6f63    41
# 8e6b41411e5129    40
# 7acc0bdc670548    40
#                   ..
# 5f3bdf34eb5b72     1
# 475e676fadb37d     1
# bbde7f861183c5     1
# db85c12e4f1aed     1
# 17536f834bb256     1
# Name: matchId, Length: 47950, dtype: int64

# %%
#To check the match type column of the dataset
df['matchType'].value_counts()
# Out:
# squad-fpp           438781
# duo-fpp             249927
# squad               156573
# solo-fpp            133853
# duo                  78039
# solo                 45679
# normal-squad-fpp      4286
# crashfpp              1581
# normal-duo-fpp        1400
# flaretpp               633
# normal-solo-fpp        465
# flarefpp               180
# normal-squad           135
# crashtpp                86
# normal-solo             75
# normal-duo              48
# Name: matchType, dtype: int64

# %%
#Count Plot of the match type column of the dataset
plt.figure(figsize=(30,10))
sns.countplot(df['matchType'], )
plt.title('Match Type',fontsize=15)
plt.xlabel('Match Type', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
#Outlier Detection
def detect_outliers(df):
    cols = list(df)
    outliers = pd.DataFrame(columns = ['Feature', 'Number of Outliers'])
    for column in cols:
        if column in df.select_dtypes(include=np.number).columns:
            q1 = df[column].quantile(0.25)
            q3 = df[column].quantile(0.75)
            iqr = q3 - q1
            fence_low = q1 - (1.5*iqr)
            fence_high = q3 + (1.5*iqr)
            outliers = outliers.append({'Feature':column, 'Number of Outliers':df.loc[(df[column] < fence_low) | (df[column] > fence_high)].shape[0]},ignore_index=True)
    return outliers

detect_outliers(df)
# Out:
#             Feature Number of Outliers
# 0           assists             194611
# 1            boosts              35533
# 2       damageDealt              54026
# 3             DBNOs              73607
# 4     headshotKills             187930
# 5             heals              81625
# 6         killPlace                  0
# 7        killPoints                  0
# 8             kills             129163
# 9       killStreaks              13391
# 10      longestKill             153335
# 11    matchDuration                699
# 12         maxPlace             175374
# 13        numGroups             174599
# 14       rankPoints                 21
# 15          revives             146345
# 16     rideDistance             277645
# 17        roadKills               3291
# 18     swimDistance              72617
# 19        teamKills              24387
# 20  vehicleDestroys               8366
# 21     walkDistance               6757
# 22  weaponsAcquired              19803
# ...

# %%
#To understand the kill streak column in the dataset
killstreak = df['killStreaks'].value_counts()
killstreak
# Out:
# 0     632148
# 1     368901
# 2      97301
# 3      11708
# 4       1520
# 5         84
# 6         36
# 7         16
# 9         10
# 8          7
# 13         4
# 12         2
# 10         2
# 16         1
# 20         1
# Name: killStreaks, dtype: int64

# %%
#To understand the kill streaks column in the dataset by checking the mean, median, quartiles, max 
meankills = df['killStreaks'].mean()
mediankills=df['killStreaks'].quantile(0.50)
quantile25=df['killStreaks'].quantile(0.25)
quantile75 =df['killStreaks'].quantile(0.75)
maxkills=df['killStreaks'].max()
print("The mean kills :",meankills)
print("The number of kills by 50 percent of the gamers is:",mediankills)
print("The number of kills by 25 percent of the gamers is:",quantile25)
print("The number of kills by 75 percent of the gamers is:",quantile75)
print("The maximum number of kills by the gamer is:",maxkills)
# Out:
# The mean kills : 0.5448508240678359
# The number of kills by 50 percent of the gamers is: 0.0
# The number of kills by 25 percent of the gamers is: 0.0
# The number of kills by 75 percent of the gamers is: 1.0
# The maximum number of kills by the gamer is: 20

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['killStreaks'], )
plt.title('Number of Kills',fontsize=15)
plt.xlabel('Kill Streak', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['killStreaks'], )
plt.title('Number of Kills',fontsize=15)
plt.xlabel('Kill Streak', fontsize=3)
plt.ylabel('Distribution of Number of Kills',fontsize=13)
plt.show()

# %%
#Damage Dealt column in the dataset
data=df.copy()

plt.figure(figsize=(15,10))
plt.title('Damage Dealt')
sns.distplot(data['damageDealt'])
plt.show()

# %%
#To understand the match duration of the winner
data=df[df['winPlacePerc']==1]

plt.figure(figsize=(15,10))
plt.title('Match Duration of the Winner',fontsize=15)
sns.distplot(data['matchDuration'])
plt.xlabel('Duration of the Game of Winners',fontsize=15)
plt.ylabel('Density',fontsize=10)
plt.show()

# %%
df['winPlacePerc'].value_counts()
# Out:
# 0.0000    55369
# 1.0000    31853
# 0.5000    13790
# 0.3333    10586
# 0.6667     9608
#           ...
# 0.9028        1
# 0.0290        1
# 0.2985        1
# 0.9836        1
# 0.2899        1
# Name: winPlacePerc, Length: 2557, dtype: int64

# %%
#To understand the match duration of second place player
data=df[df['winPlacePerc']==0.5]

plt.figure(figsize=(15,10))
plt.title('Match Duration of the Second Place Player',fontsize=15)
sns.distplot(data['matchDuration'])
plt.xlabel('Duration of the Game of Second Place Player',fontsize=15)
plt.ylabel('Density',fontsize=10)
plt.show()

# %%
#To understand the match duration of third place player
data=df[df['winPlacePerc']==0.3333]

plt.figure(figsize=(15,10))
plt.title('Match Duration of the Third Place Player',fontsize=15)
sns.distplot(data['matchDuration'])
plt.xlabel('Duration of the Game of Third Place Player',fontsize=15)
plt.ylabel('Density',fontsize=10)
plt.show()

# %%
#Win Place vs Kill Streaks
plt.figure(figsize=(20,20))
sns.jointplot(x='winPlacePerc', y='killStreaks', data=df, color='g')
plt.title('Win place vs Kill Streaks')
plt.xlabel('Win Place Prec', fontsize=15)
plt.ylabel('Kill streaks',fontsize=13)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.jointplot(x='winPlacePerc', y='damageDealt', data=df, color='purple')
plt.title('Win place vs Damage Dealt')
plt.xlabel('Win Place Prec', fontsize=15)
plt.ylabel('Damage Dealt',fontsize=13)
plt.show()

# %%
#Team Kills 
teammeankills = df['teamKills'].mean()
teammediankills=df['teamKills'].quantile(0.50)
teamquantile25=df['teamKills'].quantile(0.25)
teamquantile75 =df['teamKills'].quantile(0.75)
teammaxkills=df['teamKills'].max()
print("The mean number of team kills :",meankills)
print("The number of team kills by 50 percent of the gamers is:",teammediankills)
print("The number of team kills by 25 percent of the gamers is:",teamquantile25)
print("The number of team kills by 75 percent of the gamers is:",teamquantile75)
print("The maximum number of team kills by the gamer is:",teammaxkills)
# Out:
# The mean number of team kills : 0.5448508240678359
# The number of team kills by 50 percent of the gamers is: 0.0
# The number of team kills by 25 percent of the gamers is: 0.0
# The number of team kills by 75 percent of the gamers is: 0.0
# The maximum number of team kills by the gamer is: 10

# %%
#To understand the total distance covered by the player in the dataset by creating a new column as a sum of 
#walk distance, ride distance and swin distance
data=df.copy()
data['Total Distance Covered']=df['walkDistance']+df['rideDistance']+df['swimDistance']

print("The average distance travelled : {:.2f}".format(data['Total Distance Covered'].mean()))
print("The median distance travelled : {:.2f}".format(data['Total Distance Covered'].quantile(0.5)))
print("The distance travelled atleast 75% of the players: {:.2f}".format(data['Total Distance Covered'].quantile(0.75)))
print("The distance travelled atleast 25% of the players: {:.2f}".format(data['Total Distance Covered'].quantile(0.25)))
print("The maximum distance covered by player in the dataset: {:.2f}".format(data['Total Distance Covered'].max()))
# Out:
# The average distance travelled : 1762.04
# The median distance travelled : 785.40
# The distance travelled atleast 75% of the players: 2724.00
# The distance travelled atleast 25% of the players: 158.30
# The maximum distance covered by player in the dataset: 37312.00

# %%
#Win Place vs Total Distance Covered by the player
sns.jointplot(x='winPlacePerc', y='Total Distance Covered', data=data, ratio=3, color='blue')

# %%
#Heal time 
print("The average healing item used {:.2f}".format(df['heals'].mean()))
print("The median healing item used {:.2f}".format(df['heals'].quantile(0.5)))
print("The healing item used by atleast 25% of players {:.2f}".format(df['heals'].quantile(0.25)))
print("The healing item used by atleast 75% of players {:.2f}".format(df['heals'].quantile(0.75)))
print("The maximum healing item used by any player in the dataset {:.2f}".format(df['heals'].max()))
# Out:
# The average healing item used 1.37
# The median healing item used 0.00
# The healing item used by atleast 25% of players 0.00
# The healing item used by atleast 75% of players 2.00
# The maximum healing item used by any player in the dataset 73.00

# %%
#Boosts 
print("The average boosting item used {:.2f}".format(df['boosts'].mean()))
print("The median boosting item used {:.2f}".format(df['boosts'].quantile(0.5)))
print("The boosting item used by atleast 25% of players {:.2f}".format(df['boosts'].quantile(0.25)))
print("The boosting item used by atleast 75% of players {:.2f}".format(df['boosts'].quantile(0.75)))
print("The maximum boosting item used by any player in the dataset {:.2f}".format(df['boosts'].max()))
# Out:
# The average boosting item used 1.11
# The median boosting item used 0.00
# The boosting item used by atleast 25% of players 0.00
# The boosting item used by atleast 75% of players 2.00
# The maximum boosting item used by any player in the dataset 24.00

# %%
#Assists 
df['assists'].value_counts()
# Out:
# 0     917130
# 1     147785
# 2      34274
# 3       8887
# 4       2491
# 5        710
# 6        249
# 7         97
# 8         55
# 9         25
# 10        14
# 11         9
# 13         6
# 12         5
# 15         3
# 17         1
# Name: assists, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['assists'], )
plt.title('Assists ',fontsize=15)
plt.xlabel('Assists', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['assists'], )
plt.title('Assists ',fontsize=15)
plt.xlabel('Assists', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
#Assists
print("Average assists {:.2f}".format(df['assists'].mean()))
print("The median assists in the dataset {:.2f}".format(df['assists'].quantile(0.5)))
print("The number of assists by atleast 25% of players {:.2f}".format(df['assists'].quantile(0.25)))
print("The number of assists by atleast 75% of players {:.2f}".format(df['assists'].quantile(0.75)))
print("The number of assists by any player in the dataset {:.2f}".format(df['assists'].max()))
# Out:
# Average assists 0.23
# The median assists in the dataset 0.00
# The number of assists by atleast 25% of players 0.00
# The number of assists by atleast 75% of players 0.00
# The number of assists by any player in the dataset 17.00

# %%
#Head Shot Kills
df['headshotKills'].value_counts()
# Out:
# 0     923811
# 1     144068
# 2      31589
# 3       8185
# 4       2401
# 5        883
# 6        350
# 7        200
# 8         94
# 9         58
# 10        37
# 11        15
# 12        11
# 13        10
# 14        10
# 15         5
# 17         4
# 16         2
# 19         1
# 34         1
# 35         1
# 31         1
# 42         1
# 64         1
# 26         1
# 18         1
# Name: headshotKills, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['headshotKills'], )
plt.title('Head Shot Kills',fontsize=15)
plt.xlabel('Head Shot Kills', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
print("Average Head Shot Kills {:.2f}".format(df['headshotKills'].mean()))
print("The median head shot kills in the dataset {:.2f}".format(df['headshotKills'].quantile(0.5)))
print("The head shot kills by atleast 25% of players {:.2f}".format(df['headshotKills'].quantile(0.25)))
print("The head shot kills by atleast 75% of players {:.2f}".format(df['headshotKills'].quantile(0.75)))
print("The maximum number of head shot kills by any player in the dataset {:.2f}".format(df['headshotKills'].max()))
# Out:
# Average Head Shot Kills 0.23
# The median head shot kills in the dataset 0.00
# The head shot kills by atleast 25% of players 0.00
# The head shot kills by atleast 75% of players 0.00
# The maximum number of head shot kills by any player in the dataset 64.00

# %%
#Kill Place
df['killPlace'].value_counts()
# Out:
# 6      12143
# 4      12090
# 17     12089
# 36     12078
# 7      12055
#        ...
# 96      5598
# 97      3999
# 98      2463
# 99      1143
# 100      372
# Name: killPlace, Length: 100, dtype: int64

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['killPlace'], )
plt.title('Kill Place',fontsize=15)
plt.xlabel('Kill Place', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
#revives
df['revives'].value_counts()
# Out:
# 0     965396
# 1     117166
# 2      23775
# 3       4388
# 4        776
# 5        148
# 6         37
# 7         14
# 10         9
# 8          8
# 11         5
# 15         4
# 9          3
# 12         3
# 14         2
# 17         2
# 16         2
# 23         1
# 13         1
# 18         1
# Name: revives, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['revives'], )
plt.title('Revives',fontsize=15)
plt.xlabel('Revives', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
print("Average number of revives {:.2f}".format(df['headshotKills'].mean()))
print("The median revives in the dataset {:.2f}".format(df['headshotKills'].quantile(0.5)))
print("The number of revives atleast 25% of players {:.2f}".format(df['headshotKills'].quantile(0.25)))
print("The number of revives by atleast 75% of players {:.2f}".format(df['headshotKills'].quantile(0.75)))
print("The maximum number of revives by any player in the dataset {:.2f}".format(df['headshotKills'].max()))
# Out:
# Average number of revives 0.23
# The median revives in the dataset 0.00
# The number of revives atleast 25% of players 0.00
# The number of revives by atleast 75% of players 0.00
# The maximum number of revives by any player in the dataset 64.00

# %%
#Road Kills
df['roadKills'].value_counts()
# Out:
# 0     1108450
# 1        2835
# 2         341
# 3          76
# 4          19
# 5           8
# 6           7
# 7           2
# 9           1
# 14          1
# 8           1
# Name: roadKills, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['roadKills'], )
plt.title('Road Kills',fontsize=15)
plt.xlabel('Road Kills', fontsize=3)
plt.ylabel('Count',fontsize=13)
plt.show()

# %%
#Weapons Acquired
df['weaponsAcquired'].value_counts()
# Out:
# 2      192607
# 3      191969
# 4      172227
# 1      145307
# 5      135438
#         ...
# 96          1
# 61          1
# 95          1
# 177         1
# 58          1
# Name: weaponsAcquired, Length: 75, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['weaponsAcquired'], )
plt.title('Weapons Acquired',fontsize=15)
plt.xlabel('Weapons Acquired', fontsize=3)
plt.ylabel('Distribution of Weapons Acquired',fontsize=13)
plt.show()

# %%
#Pariwise Correlation Analysis
corrmat = df.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmat, vmax=0.9, square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The data was uploaded and the following tasks were carried out:
# - Detect Missing Values in the Dataset and rectify them
# - Perform Outlier Detection
# - Carry out Univariate Analysis in the form of barplot, histograms and countplots
# - Bivariate Analysis in the form of distribution plots
# - Multivariate Analysis in the form of Pairwise Correlation
